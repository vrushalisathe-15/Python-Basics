# %%
a=15
b=5

# %%
a+b
# Out:
# 20

# %%
a-b
# Out:
# 10

# %%
a*b
# Out:
# 75

# %%
a/b
# Out:
# 3.0

# %%
a%b
# Out:
# 0

# %%
a**b
# Out:
# 759375

# %%
a==b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a=5
a
# Out:
# 5

# %%
a+=5
a
# Out:
# 10

# %%
a-=5
a
# Out:
# 5

# %%
a*=5
a
# Out:
# 25

# %%
a/=5
a
# Out:
# 5.0

# %%
a**=2
a
# Out:
# 25.0

# %%
a%=5
a
# Out:
# 0.0

# %%
a=True
not a
# Out:
# False

# %%
a=True
b=False
a and b
# Out:
# False

# %%
a or b
# Out:
# True
