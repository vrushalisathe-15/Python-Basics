# %%
list1=[1,"Hello",3.4]
print(list1)
# Out:
# [1, 'Hello', 3.4]

# %%
list1.append(5)
list1
# Out:
# [1, 'Hello', 3.4, 5]

# %%
list1.insert(0,"V")
list1
# Out:
# ['V', 'V', 'V', 1, 'Hello', 3.4, 5]

# %%
list1.extend([8,9,7])
list1
# Out:
# ['V', 'V', 'V', 1, 'Hello', 3.4, 5, 8, 9, 7]

# %%
list1.remove("V")
list1
# Out:
# ['V', 1, 'Hello', 3.4, 5, 8, 9, 7]

# %%
list1.pop(0)
list1
# Out:
# [1, 'Hello', 3.4, 5, 8, 9, 7]

# %%
len(list1)
# Out:
# 7

# %%
list2=[4,2,7,9,5,3,9]
list2.sort()
list2
# Out:
# [2, 3, 4, 5, 7, 9, 9]

# %%
list2.sort(reverse=True)
list2
# Out:
# [9, 9, 7, 5, 4, 3, 2]

# %%
list2.reverse()
list2
# Out:
# [2, 3, 4, 5, 7, 9, 9]

# %%
4 in list2
# Out:
# True

# %%
list2.index(4)
# Out:
# 2

# %%
list1=list2.copy()
list1
# Out:
# [2, 3, 4, 5, 7, 9, 9]

# %%
max(list1)
# Out:
# 9

# %%
min(list1)
# Out:
# 2
