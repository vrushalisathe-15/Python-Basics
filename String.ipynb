# %%
a="I am learning python"

# %%
a
# Out:
# 'I am learning python'

# %%
a.upper()
# Out:
# 'I AM LEARNING PYTHON'

# %%
a.lower()
# Out:
# 'i am learning python'

# %%
a.count("a")
# Out:
# 2

# %%
a.replace("python","java")
# Out:
# 'I am learning java'

# %%
a.split()
# Out:
# ['I', 'am', 'learning', 'python']

# %%
a="   i am learning python "
a
# Out:
# '   i am learning python '

# %%
a.strip()
# Out:
# 'i am learning python'

# %%
a.lstrip()
# Out:
# 'i am learning python '

# %%
a.rstrip()
# Out:
# '   i am learning python'

# %%
a.find("python")
# Out:
# 17

# %%
a.isalpha()
# Out:
# False

# %%
a.isdigit()
# Out:
# False

# %%
a="Sdffhggxzxgfzxxzf"
a.swapcase()
# Out:
# 'sDFFHGGXZXGFZXXZF'

# %%
a="i am learning python"
a
# Out:
# 'i am learning python'

# %%
a[5:13]
# Out:
# 'learning'

# %%
a[-5:]
# Out:
# 'ython'

# %%
a[::2]
# Out:
# 'ia erigpto'

# %%
a[::-1]
# Out:
# 'nohtyp gninrael ma i'

# %%
text="hello world"
text.upper()
# Out:
# 'HELLO WORLD'

# %%
tex
