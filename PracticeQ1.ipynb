# %%
#Convert the given string into uppercase.
#text = "hello world"
text="hello world"
text.upper()
# Out:
# 'HELLO WORLD'

# %%
text.lower()
# Out:
# 'hello world'

# %%
#Count the occurrences of the letter 'o' in the given string.
text="hello world,how are you?"
text.count("o")
# Out:
# 4

# %%
# Replace all occurrences of 'apple' with 'orange' in the given string.
text="I love Apple.Apple is my favorite fruit"
text.replace("Apple","Orange")
# Out:
# 'I love Orange.Orange is my favorite fruit'

# %%
#Split the given string into a list of words.
text="Python is an amazing language"
text.split()
# Out:
# ['Python', 'is', 'an', 'amazing', 'language']

# %%
#Remove leading and trailing spaces from the given string.
text=" Hello Python "
text.strip()
# Out:
# 'Hello Python'

# %%
#Given text = "Hello, Python!", write a slice to extract "Python"
text="Hello, Python!"
start=text.find("Python")
stop=len("Python")+start
text[start:stop]
# Out:
# 'Python'

# %%
text="Let's write some python code today!"
start=text.find("code")
stop=len("code")+start
text[start:stop]
# Out:
# 'code'

# %%
string="Data Science"
string[-4:]
# Out:
# 'ence'

# %%
str="programming"
str[::-1]
# Out:
# 'gnimmargorp'

# %%
s="Machine Learning"
start=s.find("Learning")
stop=len("Learning")+start
s[start:stop]
# Out:
# 'Learning'

# %%
s="abcdefg"
s[0:6:2]
# Out:
# 'ace'
