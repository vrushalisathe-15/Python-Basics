# %%
"""1.Write a program to create a text file named sample.txt and write "Hello, Python File I/O!" into it."""
f=open("sample.txt","w")
f.write("Hello, Python File I/O!")
f.close()

# %%
"""2.Write a program to open sample.txt and read its contents."""
f=open("sample.txt","r")
content=f.read()
print(content)
f.close()
# Out:
# Hello, Python File I/O!

# %%
"""3.Write a program to append "This is an appended line." to an existing file."""
f=open("sample.txt","a")
f.write("\n This is an appended line")
f.close()

# %%
f=open("sample.txt","r")
content=f.read()
print(content)
f.close()
# Out:
# Hello, Python File I/O!
#  This is an appended line

# %%
"""4.Write a program to read a file line by line and print each line."""
f=open("sample.txt","r")
print(f.readline())
print(f.readline())
f.close()
# Out:
# Hello, Python File I/O!
#
#  This is an appended line

# %%
"""5.Write a program to count the number of characters in a file."""
f=open("sample.txt","r")
content=f.read()
print(len(content))
f.close()
# Out:
# 49

# %%
"""6.Write a program to count the number of lines in a file."""
f=open("sample.txt","r")
lines=f.readlines()
print(len(lines))
f.close()
# Out:
# 2

# %%
"""7.Write a program to count the number of words in a file."""
f=open("sample.txt","r")
content=f.read()
words=content.split()
print(len(words))
f.close()
# Out:
# 9

# %%
"""8.Write a program to read a file and print only lines that contain the word "Python"."""
f=open("sample.txt","r")
for i in f:
    if "Python" in i:
        print(i)
f.close()
# Out:
# Hello, Python File I/O!

# %%
"""9.Write a program to copy the contents of one file into another."""
f1=open("sample.txt","r")
f2=open("C.txt","w")
content=f1.read()
f2.write(content)
f1.close()
f2.close()

# %%
"""10.Write a program to reverse the contents of a file and write it to another file."""
f1=open("sample.txt","r")
f2=open("D.txt","w")
content=f1.read()
rev=content[::-1]
f2.write(rev)
f1.close()
f2.close()

# %%
#advance level

# %%
"""11.Write a program that reads a file and removes all blank lines."""
with open("sample.txt", "r") as file:
    lines = file.readlines()
with open("output.txt", "w") as file:
    for line in lines:
        if line.strip():   # checks if line is not blank
            file.write(line)

print("Blank lines removed successfully.")
# Out:
# Blank lines removed successfully.

# %%
"""12.Write a program to read a file and display the longest word in it."""
with open("sample.txt", "r") as file:
    text = file.read()
words = text.split()
longest_word = max(words, key=len)
print("Longest word:", longest_word)
print("Length:", len(longest_word))
# Out:
# Longest word: appended
# Length: 8

# %%
"""13.Write a program to merge two files into a third file."""
with open("sample.txt", "r") as f1:
    content1 = f1.read()
with open("output.txt", "r") as f2:
    content2 = f2.read()
with open("merged.txt", "w") as f3:
    f3.write(content1)
    f3.write(content2)

print("Files merged successfully.")
# Out:
# Files merged successfully.

# %%
"""15.Write a program to count how many times each word appears in a file (word frequency counter)."""
# Word Frequency Counter
filename = "sample.txt"   # file name
word_count = {}

with open(filename, "r") as file:
    for line in file:
        words = line.lower().split()   # convert to lowercase and split words
        for word in words:
            if word in word_count:
                word_count[word] += 1
            else:
                word_count[word] = 1
for word, count in word_count.items():
    print(word, ":", count)
# Out:
# hello, : 1
# python : 1
# file : 1
# i/o! : 1
# this : 1
# is : 1
# an : 1
# appended : 1
# line : 1
